# %%
import os
import pandas as pd
import numpy as np

# Benchmarks list
benchmarks = ["bert_large", "Resnet50", "UNet", "CRADL","gromacs","miniGAN"]
benchmarks = ["miniGAN"]


# Base input directory structure
input_base_dir = "./ecp_power_cap_res/2_dual_cap/{}/unfiltered/"

# Output base directory
output_base_dir = "./ecp_power_cap_res/2_dual_cap/"

# Ensure output directories exist
for benchmark in benchmarks:
    os.makedirs(os.path.join(output_base_dir, benchmark), exist_ok=True)

def process_csv_files(cpu_power, gpu_power, app_name, input_dir):
    """Process CSV files for a given CPU and GPU power combination."""
    prefix = f"{cpu_power}_{gpu_power}"
    
    # File paths
    gpu_metrics_file = os.path.join(input_dir, f"{prefix}_gpu_metrics.csv")
    cpu_power_file = os.path.join(input_dir, f"{prefix}_cpu_power.csv")
    cpu_metrics_file = os.path.join(input_dir, f"{prefix}_cpu_metrics.csv")

    # Output directory
    output_dir = os.path.join(output_base_dir, app_name)
    os.makedirs(output_dir, exist_ok=True)

    # Read GPU metrics
    df_gpu = pd.read_csv(gpu_metrics_file)
    if app_name == "UNet":
        count = 5
    elif app_name == "gromacs":
        count = 1
    elif app_name == "miniGAN":
        count = 1
    else:
        count = 15
    # Find first row where FP16 Active + FP32 Active + FP64 Active > 0 for 20 continuous rows
    fp_active = df_gpu["FP16 Active"] + df_gpu["FP32 Active"] + df_gpu["FP64 Active"]
    for i in range(len(fp_active) - count - 1):
        if all(fp_active.iloc[i:i+count] > 0):
            T = df_gpu.iloc[i]["Time (s)"]
            df_gpu = df_gpu.iloc[i:].copy()  # Keep rows from T onward
            df_gpu["Time (s)"] -= T  # Normalize time
            break
    else:
        print(f"No valid GPU activity found for {prefix}, skipping.")
        return

    # Read CPU power and metrics
    df_cpu_power = pd.read_csv(cpu_power_file)
    df_cpu_metrics = pd.read_csv(cpu_metrics_file)

    # Find nearest timestamp in CPU power and metrics files
    T_cpu_power = df_cpu_power["Time (s)"].sub(T).abs().idxmin()
    T_cpu_metrics = df_cpu_metrics["Time (s)"].sub(T).abs().idxmin()

    # Process CPU power file
    df_cpu_power = df_cpu_power.iloc[T_cpu_power:].copy()
    df_cpu_power["Time (s)"] -= df_cpu_power.iloc[0]["Time (s)"]

    # Process CPU metrics file
    df_cpu_metrics = df_cpu_metrics.iloc[T_cpu_metrics:].copy()
    df_cpu_metrics["Time (s)"] -= df_cpu_metrics.iloc[0]["Time (s)"]

    # Save processed files
    df_gpu.to_csv(os.path.join(output_dir, f"{prefix}_gpu_metrics.csv"), index=False)
    df_cpu_power.to_csv(os.path.join(output_dir, f"{prefix}_cpu_power.csv"), index=False)
    df_cpu_metrics.to_csv(os.path.join(output_dir, f"{prefix}_cpu_metrics.csv"), index=False)

    print(f"Processed {prefix} and saved in {output_dir}")

# Iterate over specified benchmarks
for benchmark in benchmarks:
    input_dir = input_base_dir.format(benchmark)
    
    if not os.path.exists(input_dir):
        print(f"Input directory {input_dir} does not exist, skipping {benchmark}.")
        continue

    for filename in os.listdir(input_dir):
        if "_gpu_metrics.csv" in filename:
            parts = filename.split("_")
            cpu_power, gpu_power = parts[0], parts[1]
            process_csv_files(cpu_power, gpu_power, benchmark, input_dir)
# Out:
# Processed 200_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_250 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_180 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_220 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_210 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_200 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 160_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 180_160 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 200_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 120_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 130_190 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_240 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 190_150 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 150_230 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 140_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
# Processed 170_170 and saved in ./ecp_power_cap_res/2_dual_cap/miniGAN
